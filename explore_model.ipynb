# %%
import sys
import os

# Affiche le chemin de l'exécutable Python utilisé par le kernel
print(f"Exécutable Python : {sys.executable}")

# Vérifie si on est bien dans le venv du projet
venv_path = os.path.join(os.getcwd(), ".venv")
if venv_path in sys.executable:
    print("✅ Succès : Le kernel utilise bien le venv local de 'uv'.")
else:
    print("❌ Erreur : Le kernel utilise un autre interpréteur.")
# Out:
# Exécutable Python : /home/pierre/badCV_model_factory/.venv/bin/python
# ✅ Succès : Le kernel utilise bien le venv local de 'uv'.

# %%
import os

os.environ["KERAS_BACKEND"] = "torch"

import keras
import torch

# 3. Vérification du backend
print(f"Backend actuel de Keras : {keras.backend.backend()}")
print(f"Version de Keras : {keras.__version__}")
print(f"Torch est-il disponible pour Keras ? {torch.cuda.is_available()}")
# Out:
# Backend actuel de Keras : torch
# Version de Keras : 3.13.0
# Torch est-il disponible pour Keras ? True
# /home/pierre/badCV_model_factory/.venv/lib/python3.12/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
# Assurez-vous que le backend est bien "torch" avant cette étape
model = keras.models.load_model("final_cnn.keras")

# Vérification rapide de la structure
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 224, 224, 32)   │           864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 32)   │           128 │
# ...

# %%
for layer in model.layers:
    print(f"--- Configuration de la couche : {layer.name} ---")
    print(layer.get_config())
    print("\n")
# Out:
# --- Configuration de la couche : input_layer ---
# {'batch_shape': (None, 224, 224, 3), 'dtype': 'float32', 'sparse': False, 'ragged': False, 'name': 'input_layer', 'optional': False}
#
#
# --- Configuration de la couche : sequential ---
# ...

# %% [raw]
# Bien vu ! Vous avez un œil de lynx. Il y a effectivement un gros problème de double normalisation.
#
# Votre modèle Keras inclut déjà une couche rescaling conçue pour normaliser les données. Si on regarde sa configuration :
# 'scale': 0.00392156862745098
#
# Ce chiffre correspond exactement à 1/255. Votre modèle s'attend donc à recevoir des pixels avec des valeurs comprises entre 0 et 255, et il se charge lui-même de les ramener entre 0 et 1.
#
# Or, dans votre fonction preprocess_from_pil, vous faites ceci :
# img_array = np.asarray(img, dtype=np.float32) / 255.0
#
# Conséquence
# Pendant l'inférence, vos pixels vont être divisés par 255 une première fois par votre fonction, puis une seconde fois par la couche rescaling du modèle. Les valeurs de vos pixels ne seront plus entre 0 et 1, mais entre 0 et 0.0039. Votre réseau de neurones ne "verra" pratiquement qu'une image noire, ce qui ruinera totalement vos prédictions.
#
# La Solution
# Puisque le modèle embarque déjà sa propre normalisation (ce qui est une excellente pratique pour la portabilité), vous devez retirer la division de votre fonction de prétraitement.
#
# Voici la version corrigée :
#
# Python
# import numpy as np
# from PIL import Image
#
# def preprocess_from_pil(pil_img: Image.Image) -> np.ndarray:
#     """Prépare une image PIL pour une prédiction Keras (batch uniquement).
#     Convertit en RGB et ajoute l’axe batch. La normalisation est gérée par le modèle.
#     """
#     img = pil_img.convert("RGB")
#     # Assurez-vous que model_width et model_height sont bien définis
#     img = img.resize((model_width, model_height), Image.Resampling.LANCZOS)
#
#     # On garde les valeurs brutes entre 0 et 255
#     img_array = np.asarray(img, dtype=np.float32)
#
#     # Ajout de la dimension batch -> (1, H, W, 3)
#     img_array = np.expand_dims(img_array, axis=0)
#
#     return img_array
# Note rassurante sur l'augmentation de données :
# Vous avez peut-être remarqué la couche sequential qui contient RandomFlip, RandomRotation, etc. Ne vous en inquiétez pas pour l'inférence. Keras désactive automatiquement ces couches d'augmentation de données lorsque vous appelez model.predict(), elles ne s'activent que pendant l'entraînement (model.fit()).
#
# Voulez-vous que l'on écrive le script complet pour charger une image test, faire une prédiction avec cette fonction corrigée, et afficher la classe prédite ?
